# %%
from pathlib import Path

ORIGINAL_DIR = Path(r"asyncio\youtube_tutorial").absolute() / "original_images"
ORIGINAL_DIR
# Out:
# WindowsPath('e:/LifeStyle/Python学习/modules_learn/asyncio/asyncio/youtube_tutorial/original_images')
